# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# part-2 task-1
table = pd.read_csv('2017_jun_final.csv')

# part-2 task-2
table.head()
# Out:
#    N                 Должность Язык.программирования Специализация  \
# 0  1        Junior QA engineer                   NaN     Manual QA
# 1  2        Junior QA engineer                   NaN     Manual QA
# 2  3         Software Engineer               C#/.NET           NaN
# 3  4         Software Engineer            JavaScript           NaN
# 4  5  Senior Software Engineer            JavaScript           NaN
#
#   Общий.опыт.работы Опыт.работы.на.текущем.месте  Зарплата.в.месяц  \
# 0               0.5                          0.5               400
# 1  меньше 3 месяцев             меньше 3 месяцев               430
# 2                 4                            1              2500
# 3                 5                            4              2000
# 4    10 и более лет                          0.5              4500
#
#    Изменение.зарплаты.за.12.месяцев    Город     Размер.компании  ...  \
# 0                                 0  Харьков       до 10 человек  ...
# ...

# %%
# part-2 task-3

rows, columns = table.shape

print("Кількість рядків:", rows)
print("Кількість стовпців:", columns)
# Out:
# Кількість рядків: 8704
# Кількість стовпців: 25

# %%
# part-2 task-4

# Визначення типів стовпців за допомогою атрибуту dtypes
column_types = table.dtypes

# Виведення результатів
print("Типи стовпців:")
print(column_types)
# Out:
# Типи стовпців:
# N                                     int64
# Должность                            object
# Язык.программирования                object
# Специализация                        object
# Общий.опыт.работы                    object
# Опыт.работы.на.текущем.месте         object
# Зарплата.в.месяц                      int64
# Изменение.зарплаты.за.12.месяцев      int64
# Город                                object
# Размер.компании                      object
# Тип.компании                         object
# Пол                                  object
# Возраст                               int64
# Образование                          object
# Университет                          object
# Еще.студент                            bool
# Уровень.английского                  object
# Предметная.область                   object
# Дата.заполнения                      object
# User.Agent                           object
# exp                                 float64
# ...

# %%
# part-1 task-5
missing_values = table.isnull().sum()

# # частку пропусків у кожній колонці
missing_percentage = missing_values/table.shape[0]

# результfn
result_df = pd.DataFrame({
    'Кількість пропусків': missing_values,
    'Частка пропусків (%)': missing_percentage
})
print(result_df)
# Out:
#                                   Кількість пропусків  Частка пропусків (%)
# N                                                   0              0.000000
# Должность                                           0              0.000000
# Язык.программирования                            3850              0.442325
# Специализация                                    7219              0.829389
# Общий.опыт.работы                                   0              0.000000
# Опыт.работы.на.текущем.месте                        0              0.000000
# Зарплата.в.месяц                                    0              0.000000
# Изменение.зарплаты.за.12.месяцев                    0              0.000000
# Город                                               0              0.000000
# Размер.компании                                     0              0.000000
# Тип.компании                                        0              0.000000
# ...

# %%
# part-1 task-6
table_v2 = table.drop(labels=["Специализация", "Университет", "Предметная.область", "Валюта", "cls"], axis=1)

# %%
# part-1 task-7
missing_values = table_v2.isnull().sum()

# # частку пропусків у кожній колонці
missing_percentage = missing_values/table_v2.shape[0]

# результfn
result_df = pd.DataFrame({
    'Кількість пропусків': missing_values,
    'Частка пропусків (%)': missing_percentage
})
print(result_df)
# Out:
#                                   Кількість пропусків  Частка пропусків (%)
# N                                                   0              0.000000
# Должность                                           0              0.000000
# Язык.программирования                            3850              0.442325
# Общий.опыт.работы                                   0              0.000000
# Опыт.работы.на.текущем.месте                        0              0.000000
# Зарплата.в.месяц                                    0              0.000000
# Изменение.зарплаты.за.12.месяцев                    0              0.000000
# Город                                               0              0.000000
# Размер.компании                                     0              0.000000
# Тип.компании                                        0              0.000000
# Пол                                                 0              0.000000
# ...

# %%
# part-1 task-8
table_v3 = table_v2.dropna()
table_v3
# Out:
#          N                 Должность Язык.программирования Общий.опыт.работы  \
# 2        3         Software Engineer               C#/.NET                 4
# 3        4         Software Engineer            JavaScript                 5
# 4        5  Senior Software Engineer            JavaScript    10 и более лет
# 6        7  Junior Software Engineer               C#/.NET                 1
# 7        8  Senior Software Engineer                   C++                 6
# ...    ...                       ...                   ...               ...
# 8692  8693         Software Engineer                  Java                 5
# 8694  8695  Junior Software Engineer               C#/.NET                 1
# 8695  8696         Software Engineer                Python                 1
# 8701  8702  Junior Software Engineer            Ruby/Rails                 1
# 8703  8704  Senior Software Engineer                  Java                 7
#
# ...

# %%
# part-2 task-9

rows, columns = table_v3.shape

print("Кількість рядків:", rows)
print("Кількість стовпців:", columns)
# Out:
# Кількість рядків: 4854
# Кількість стовпців: 20

# %%
# part-2 task-10
python_data = table_v3[table_v3['Язык.программирования'] == 'Python']
python_data
# Out:
#          N                 Должность Язык.программирования Общий.опыт.работы  \
# 12      13         Software Engineer                Python                 1
# 68      69         Software Engineer                Python               1.5
# 87      88  Junior Software Engineer                Python               0.5
# 114    115  Junior Software Engineer                Python               1.5
# 143    144  Junior Software Engineer                Python                 1
# ...    ...                       ...                   ...               ...
# 8546  8547         Software Engineer                Python                 5
# 8625  8626         Software Engineer                Python                 4
# 8635  8636  Senior Software Engineer                Python    10 и более лет
# 8673  8674  Junior Software Engineer                Python               0.5
# 8695  8696         Software Engineer                Python                 1
#
# ...

# %%
# part-2 task-11

rows, columns = python_data.shape

print("Кількість рядків:", rows)
print("Кількість стовпців:", columns)
# Out:
# Кількість рядків: 207
# Кількість стовпців: 20

# %%
# part-2 task-12

grouped_table = python_data.groupby('Должность')
print(grouped_table.size())
print(grouped_table)
# Out:
# Должность
# Junior Software Engineer     63
# Senior Software Engineer     31
# Software Engineer           100
# System Architect              2
# Technical Lead               11
# dtype: int64
# ...

# %%
# part-2 task-13

aggregated_data = grouped_table.agg({'Зарплата.в.месяц': ['min', 'max']})

# Перейменування стовпців для зручності
aggregated_data.columns = ['Мінімальна зарплата', 'Максимальна зарплата']

print(aggregated_data)
# Out:
#                           Мінімальна зарплата  Максимальна зарплата
# Должность
# Junior Software Engineer                  100                  1250
# Senior Software Engineer                 1300                  9200
# Software Engineer                         500                  5400
# System Architect                         3000                  5000
# Technical Lead                           1425                  6200

# %%
# part-2 task-14

# Приклад функції fill_avg_salary
def fill_avg_salary(row):
    return row.mean()

update_table = aggregated_data.apply(fill_avg_salary, axis=1, result_type='expand')
update_table.name = "Середня зарплата"
final_update_table = pd.concat([aggregated_data, update_table], axis=1)
final_update_table
# Out:
#                           Мінімальна зарплата  Максимальна зарплата  \
# Должность
# Junior Software Engineer                  100                  1250
# Senior Software Engineer                 1300                  9200
# Software Engineer                         500                  5400
# System Architect                         3000                  5000
# Technical Lead                           1425                  6200
#
#                           Середня зарплата
# Должность
# Junior Software Engineer             675.0
# Senior Software Engineer            5250.0
# Software Engineer                   2950.0
# System Architect                    4000.0
# Technical Lead                      3812.5

# %%
# part-2 task-15

final_update_table['Середня зарплата'].describe()
# Out:
# count       5.000000
# mean     3337.500000
# std      1700.091909
# min       675.000000
# 25%      2950.000000
# 50%      3812.500000
# 75%      4000.000000
# max      5250.000000
# Name: Середня зарплата, dtype: float64

# %%
# part-2 task-16

final_update_table.to_csv("final_statistics.csv")

# %%
import seaborn as sns
df = pd.read_csv('final_statistics.csv')

sns.barplot(data=df)
plt.show()
